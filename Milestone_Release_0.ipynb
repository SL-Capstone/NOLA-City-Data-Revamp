# %% [markdown]
# # **DataDriven.Nola.gov Data Analysis**

# %%
# Install necessary libraries
# !pip install bertopic
# !pip install geopandas
import pandas as pd
import geopandas as gpd
import spacy
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
import shapely
from shapely.geometry import Point, Polygon
from shapely import wkt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic
#   Downloading bertopic-0.13.0-py2.py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.9/103.9 KB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.8/dist-packages (from bertopic) (1.21.6)
# Collecting hdbscan>=0.8.29
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 51.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.8/dist-packages (from bertopic) (1.3.5)
# Collecting pyyaml<6.0
#   Downloading PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.4/662.4 KB 49.7 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.8/dist-packages (from bertopic) (5.5.0)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.8/dist-packages (from bertopic) (1.0.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.8/dist-packages (from bertopic) (4.64.1)
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.8/dist-packages (from hdbscan>=0.8.29->bertopic) (1.7.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.8/dist-packages (from hdbscan>=0.8.29->bertopic) (1.2.0)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.8/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.33)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.5->bertopic) (2022.7)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from plotly>=4.7.0->bertopic) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from plotly>=4.7.0->bertopic) (8.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.26.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 91.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic) (1.13.1+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.14.1+cu116)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.9 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 25.1 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.8/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.25.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (6.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 98.4 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.49->umap-learn>=0.5.0->bertopic) (3.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.10)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp38-cp38-linux_x86_64.whl size=3773942 sha256=0d784f2d004c5244b0c45663d6c8a45b4cd31505909e71d0b47d256661594668
#   Stored in directory: /root/.cache/pip/wheels/76/06/48/527e038689c581cc9e519c73840efdc7473805149e55bd7ffd
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=c9564d68a44b00b193b165aa9532ca519254bae567339e78ef768c36bd31d948
#   Stored in directory: /root/.cache/pip/wheels/5e/6f/8c/d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=3ea3c5b856d2e8a639dc0202973d775e1ab079c1fcd2d5762b711fcc85b6adb3
#   Stored in directory: /root/.cache/pip/wheels/a9/3a/67/06a8950e053725912e6a8c42c4a3a241410f6487b8402542ea
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55513 sha256=d0e13344e8bf86dfc516fc00846af7a440427eb59b620e7289c11560988c74d7
#   Stored in directory: /root/.cache/pip/wheels/1c/63/3a/29954bca1a27ba100ed8c27973a78cb71b43dc67aed62e80c3
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, pyyaml, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# Successfully installed bertopic-0.13.0 hdbscan-0.8.29 huggingface-hub-0.12.0 pynndescent-0.5.8 pyyaml-5.4.1 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.2 transformers-4.26.0 umap-learn-0.5.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.1 MB/s eta 0:00:00
# Collecting fiona>=1.8
#   Downloading Fiona-1.9.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 65.4 MB/s eta 0:00:00
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 101.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from geopandas) (1.3.5)
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.8/dist-packages (from geopandas) (2.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from geopandas) (21.3)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (22.2.0)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click~=8.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 KB 12.0 MB/s eta 0:00:00
# Collecting munch>=2.3.2
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from fiona>=1.8->geopandas) (2022.12.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas) (2022.7)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->geopandas) (3.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.15.0)
# Installing collected packages: pyproj, munch, click, cligj, click-plugins, fiona, geopandas
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.1.3 which is incompatible.
# Successfully installed click-8.1.3 click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.0 geopandas-0.12.2 munch-2.5.0 pyproj-3.4.1
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %% [markdown]
# ### **Public Records Requests**
# Using BERTopic, we performed topic modeling on the public records requests data to gauge community data interests and determine the most frequently requested data topics. By manipulating the parameters, we trained four different models, and the topics showing up in the results of all four models were deemed the most important/relevant data topics.

# %%
#requests data - convert to list of strings
requests = pd.read_csv('Public_Records_Requests.csv')
display(requests['Request Text'].head())
requests = requests['Request Text'].tolist()
# Out:
# 0    Any and all contracts between the city of New ...
# 1    Hello, hoping to get any records of hazardous ...
# 2    Please send me a copy of all pre and post tax ...
# 3    Please provide the following information about...
# 4    I am requesting public records of the city's e...
# Name: Request Text, dtype: object

# %% [markdown]
# Below, we train our first model. We end up with the most frequently appearing topics in the data, each represented by a set of words. The 20 most frequent topics are displayed in the chart below.

# %%
# training
topic_model_1 = BERTopic(language="english", calculate_probabilities=True, verbose=True)
topics, probs = topic_model_1.fit_transform(requests)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Batches:   0%|          | 0/242 [00:00<?, ?it/s]
# 2023-02-01 22:13:43,280 - BERTopic - Transformed documents to Embeddings
# 2023-02-01 22:14:22,458 - BERTopic - Reduced dimensionality
# 2023-02-01 22:14:29,443 - BERTopic - Clustered reduced embeddings

# %%
# save model 1
topic_model_1.save("PublicRecords_Model1")

# %%
# most frequent topics: -1 indicates outliers, ignore
freq = topic_model_1.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                   Name
# 0      -1   2456                       -1_the_and_of_to
# 1       0    341                  0_paid_bill_taxes_tax
# 2       1    228        1_fire_report_occurred_incident
# 3       2    145        2_accident_camera_video_footage
# 4       3    126     3_rfp_proposals_proposal_selection
# 5       4    122         4_hearing_case_audio_recording
# 6       5    119        5_fire_report_incident_occurred
# 7       6    106          6_public_records_fees_request
# 8       7     95     7_contract_contracts_city_services
# 9       8     94         8_incident_initial_report_view
# 10      9     77  9_permit_permits_seasons_applications
# 11     10     76         10_sale_tax_adjudicated_notice
# 12     11     73              11_street_909_new_orleans
# 13     12     73           12_code_violations_open_fire
# 14     13     70        13_body_footage_camera_accident
# 15     14     68       14_emails_january_email_received
# 16     15     67            15_death_im_caitlin_ostroff
# 17     16     66        16_public_record_requested_nopd
# 18     17     61             17_send_immovable_post_pre
# 19     18     56            18_911_call_audio_calltaker

# %% [markdown]
# The most frequent topic in the public records requests apprears to be fire incident reports in New Orleans. Below is the cluster of words representing this topic.

# %%
topic_model_1.get_topic(0) # get the most frequent topic
# Out:
# [('paid', 0.04051794162392834),
#  ('bill', 0.03192764909120962),
#  ('taxes', 0.030158615439760006),
#  ('tax', 0.02682242955782168),
#  ('bills', 0.018688996812009098),
#  ('payment', 0.018297616759302002),
#  ('years', 0.01792659410897716),
#  ('property', 0.016692182270005525),
#  ('need', 0.016042050463513816),
#  ('st', 0.0151604354204308)]

# %% [markdown]
# The second most frequent topic is related to traffic camera footage.

# %%
topic_model_1.get_topic(1) # get the 2nd most frequent topic
# Out:
# [('fire', 0.05021988262461151),
#  ('report', 0.03395581522289028),
#  ('occurred', 0.029082923704072616),
#  ('incident', 0.024463732108309922),
#  ('la', 0.02288128532612857),
#  ('involving', 0.018822681936579724),
#  ('new', 0.017495577670789905),
#  ('orleans', 0.01733343284982858),
#  ('on', 0.016995891077716898),
#  ('at', 0.016418805691181572)]

# %% [markdown]
# Based on the relationship between the words representing each topic, we label each topic and display the 10 most frequent topics below.

# %%
# Set labels for top 10 topics
topic_model_1.set_topic_labels({0: "Fire Incident", 1: "Traffic Camera Footage",
                                2: "Fire Incident", 3: "RFP", 4: "Public Records Requests",
                                5: "Tax Payment", 6: "Street Permits", 7: "Incident Reports",
                                8: "Taxes", 9: "Emails"})

# Display model 1 bar chart
topic_model_1.visualize_barchart(top_n_topics=10, title='Model 1: Topic Word Scores',
                                 custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0f7a4827-f2b7-4297-8768-3167b4788b01" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f7a4827-f2b7-4297-8768-3167b4788b01")) {                    Plotly.newPlot(                        "0f7a4827-f2b7-4297-8768-3167b4788b01",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.018688996812009098,0.02682242955782168,0.030158615439760006,0.03192764909120962,0.04051794162392834],"y":["bills  ","tax  ","taxes  ","bill  ","paid  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.02288128532612857,0.024463732108309922,0.029082923704072616,0.03395581522289028,0.05021988262461151],"y":["la  ","incident  ","occurred  ","report  ","fire  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.030128724723725027,0.030492391206130353,0.03050533378277159,0.030938908234288204,0.031228320792525088],"y":["intersection  ","footage  ","video  ","camera  ","accident  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.022582200880886836,0.02337832454671336,0.02604714786057989,0.03130421190388024,0.05787635188479944],"y":["evaluation  ","selection  ","proposal  ","proposals  ","rfp  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.01546143413454253,0.017609158823111287,0.020580717588105635,0.028352899702917593,0.06136132635806535],"y":["evidence  ","recording  ","audio  ","case  ","hearing  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.020694389642199825,0.02448650056473837,0.0558145003153862,0.0577769669720224,0.08238071139443541],"y":["on  ","occurred  ","incident  ","report  ","fire  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.009117049964652768,0.009349280788980455,0.009423588097534397,0.009926888969559016,0.013768229915549945],"y":["act  ","request  ","fees  ","records  ","public  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.017946127290744407,0.021223177648136925,0.02148270860185622,0.025829632007037535,0.03002658275852929],"y":["between  ","services  ","city  ","contracts  ","contract  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.022764747658067398,0.035086527641880444,0.04007703950081487,0.06370410082768414,0.08440038498683583],"y":["item  ","view  ","report  ","initial  ","incident  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.017959383079133834,0.0179643296147843,0.01922238332556232,0.041403690988876474,0.050714881113192924],"y":["issued  ","applications  ","seasons  ","permits  ","permit  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outli ...

# %% [markdown]
# Now, we update the topics from model 1 by modifying the parameters. By changing the N-gram range, we can control how many words are included in each entity of a topic. This is set to its default value of 1 in our original model, meaning that each topic is represented by a group of singular words. We now change this to a range of (1, 3), so each entity in a topic can be up to 3 words. For example, "New" and "Orleans" are two separate words, but can now be considered as a single term "New Orleans" in our topic representation. Let's see how this affects our results.

# %%
# change ngram_range, let each entity in a topic be up to 3 words
vectorizer_model = CountVectorizer(ngram_range=(1, 3))

# update model 1
topic_model_1.update_topics(requests, vectorizer_model=vectorizer_model)

# %%
# get most frequent topics: ngram_range = (1,3)
freq = topic_model_1.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                               Name  \
# 0      -1   2456                                   -1_the_and_of_to
# 1       0    341                              0_paid_tax_bill_taxes
# 2       1    228                 1_fire_report_the fire_fire report
# 3       2    145                    2_camera_accident_footage_video
# 4       3    126                    3_rfp_proposals_proposal_rfp no
# 5       4    122                   4_hearing_case_the hearing_audio
# 6       5    119                 5_fire_report_incident_fire report
# 7       6    106            6_public_records_request_public records
# 8       7     95               7_contract_the city_city_the city of
# 9       8     94  8_incident_initial incident_incident report_in...
# 10      9     77                   9_permit_permits_all permits_llc
# 11     10     76                        10_sale_tax sale_tax_notice
# 12     11     73  11_street_street new orleans_street new_new or...
# 13     12     73  12_fire code_fire code violations_code violati...
# 14     13     70                    13_body_footage_camera_accident
# 15     14     68      14_emails_nbsp nbsp nbsp_all emails_nbsp nbsp
# 16     15     67                        15_death_im_caitlin_ostroff
# 17     16     66   16_public_public record_records_requested public
# 18     17     61       17_send_tax_pre and post_sale notices issued
# 19     18     56                          18_911_call_the 911_audio
#
#                           CustomName
# 0                   -1_the_and_of_to
# 1                      Fire Incident
# 2             Traffic Camera Footage
# 3                      Fire Incident
# 4                                RFP
# 5            Public Records Requests
# 6                        Tax Payment
# 7                     Street Permits
# 8                   Incident Reports
# 9                              Taxes
# 10                            Emails
# 11    10_sale_tax_adjudicated_notice
# 12         11_street_909_new_orleans
# 13      12_code_violations_open_fire
# 14   13_body_footage_camera_accident
# 15  14_emails_january_email_received
# 16       15_death_im_caitlin_ostroff
# 17   16_public_record_requested_nopd
# 18        17_send_immovable_post_pre
# 19       18_911_call_audio_calltaker

# %% [markdown]
# After changing the N-gram range, our most frequent topics have changed slightly, but there are still similarities to our original model. Some notable topics include **fire incident reports, body camera footage, and 911 calls.**

# %% [markdown]
# We will now manipulate the BERTopic parameters to create a new model. By changing the minimum topic size to 5 (from its default value of 10), topics can be comprised of less words. Lowering this value means that more topics are created. Shown below is a chart of the 20 most frequent topics using model 2.

# %%
# train a new model with modified topic sizes (min topic size = 5)
topic_model_2 = BERTopic(language="english", min_topic_size=5, calculate_probabilities=True, verbose=True)
topics, probs = topic_model_2.fit_transform(requests)
# Out:
# Batches:   0%|          | 0/242 [00:00<?, ?it/s]
# 2023-02-01 22:22:34,088 - BERTopic - Transformed documents to Embeddings
# 2023-02-01 22:22:49,225 - BERTopic - Reduced dimensionality
# 2023-02-01 22:23:10,600 - BERTopic - Clustered reduced embeddings

# %%
# save model 2
topic_model_2.save("PublicRecords_Model2")

# %%
# most frequent topics: model 2
freq = topic_model_2.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                      Name
# 0      -1   2322                          -1_the_and_in_of
# 1       0    220           0_fire_report_occurred_incident
# 2       1    176                   1_paid_bill_taxes_bills
# 3       2    100     2_intersection_video_accident_footage
# 4       3     98            3_incident_initial_report_view
# 5       4     82            4_hearing_audio_case_recording
# 6       5     81     5_permit_permits_seasons_applications
# 7       6     80     6_contract_contracts_services_between
# 8       7     80            7_rfp_proposals_sheets_scoring
# 9       8     65            8_emails_january_between_email
# 10      9     65                 9_immovable_send_post_pre
# 11     10     63            10_bid_tabulations_unit_prices
# 12     11     59  11_monuments_monument_removal_beauregard
# 13     12     57            12_bid_pavement_pw_restoration
# 14     13     56               13_911_audio_call_calltaker
# 15     14     52                14_909_street_photos_canal
# 16     15     49   15_signal_traffic_intersection_sequence
# 17     16     48              16_fire_report_copy_occurred
# 18     17     45                 17_sale_tax_notice_giving
# 19     18     45        18_violations_code_nicole_thompson

# %% [markdown]
# The two most frequent topics are related to tax payments and fire incidents. The word groups representing these topics are displayed below.

# %%
topic_model_2.get_topic(0) # get the most frequent topic
# Out:
# [('fire', 0.03532126319801001),
#  ('report', 0.02500393287694658),
#  ('occurred', 0.024305347023232952),
#  ('incident', 0.019710359111971523),
#  ('involving', 0.016900191660993873),
#  ('la', 0.016786606445324377),
#  ('new', 0.01153911639001556),
#  ('on', 0.011434470872834971),
#  ('orleans', 0.011308420676572619),
#  ('at', 0.011166430095734916)]

# %%
topic_model_2.get_topic(1) # get the 2nd most frequent topic
# Out:
# [('paid', 0.036708768989720926),
#  ('bill', 0.029973690889021142),
#  ('taxes', 0.024621042014229568),
#  ('bills', 0.024404672845004326),
#  ('tax', 0.02169817552046533),
#  ('nola', 0.01819465432362737),
#  ('st', 0.014998872357907663),
#  ('payment', 0.01491190743482294),
#  ('amount', 0.013340573279836333),
#  ('years', 0.012075635108805738)]

# %%
# Set labels for top 10 topics
topic_model_2.set_topic_labels({0: "Tax Payments", 1: "Fire Incident",
                                2: "Traffic Camera Footage", 3: "RFP", 4: "Incident Reports",
                                5: "Permit Applications", 6: "Code Violations", 7: "Pricing",
                                8: "Body Camera Footage", 9: "Fire Incident"})

# Display model 2 bar chart
topic_model_2.visualize_barchart(top_n_topics=10, title='Model 2: Topic Word Scores',
                                 custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5542a9d8-8049-4c40-824f-d12af74d2b24" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5542a9d8-8049-4c40-824f-d12af74d2b24")) {                    Plotly.newPlot(                        "5542a9d8-8049-4c40-824f-d12af74d2b24",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.016900191660993873,0.019710359111971523,0.024305347023232952,0.02500393287694658,0.03532126319801001],"y":["involving  ","incident  ","occurred  ","report  ","fire  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.02169817552046533,0.024404672845004326,0.024621042014229568,0.029973690889021142,0.036708768989720926],"y":["tax  ","bills  ","taxes  ","bill  ","paid  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.024074921824447676,0.024413921479802893,0.02572404297411418,0.025865915879480617,0.02633620525910754],"y":["camera  ","footage  ","accident  ","video  ","intersection  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.018188514001600434,0.030813090539720457,0.03250685963799588,0.05454723262355333,0.06894303242016354],"y":["supplemental  ","view  ","report  ","initial  ","incident  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.013544942197020663,0.01657037585201634,0.01858864437723907,0.019596128220609185,0.05050472226062638],"y":["2018  ","recording  ","case  ","audio  ","hearing  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.011942320472599247,0.013971396930341917,0.014767916032793007,0.028291068553155652,0.033901599720174036],"y":["issued  ","applications  ","seasons  ","permits  ","permit  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.014215297746379588,0.014435056267499783,0.01828680775757912,0.021123083188915908,0.022325376273286842],"y":["city  ","between  ","services  ","contracts  ","contract  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.0268667079981034,0.02714794335236453,0.027464310011859935,0.034698507915411105,0.07200437580442746],"y":["design  ","scoring  ","sheets  ","proposals  ","rfp  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.014131529681289615,0.014840003192694965,0.016292422467005824,0.021552434532119507,0.02834707155975099],"y":["appearing  ","email  ","between  ","january  ","emails  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.03296251941623299,0.038298896829151205,0.04031878286896051,0.04650075617270924,0.04700563800050023],"y":["entity  ","pre  ","post  ","send  ","immovable  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"col ...

# %% [markdown]
# Now, we will train a new model with a topic size of 5. Previously, the size of each topic was greater than or equal to 5; we now restrict all topic sizes to 5 by changing the top_n_words parameter. The more words that are included in a topic, the less coherent that topic can become. This should create more focused topics; let's see how it affects our results. Below are the most frequent topics produced by this model.

# %%
# train a new model with modified topic sizes (topic size = 5)
topic_model_3 = BERTopic(language="english", top_n_words=5, min_topic_size=5,
                         calculate_probabilities=True, verbose=True)
topics, probs = topic_model_3.fit_transform(requests)
# Out:
# Batches:   0%|          | 0/242 [00:00<?, ?it/s]
# 2023-02-01 22:30:38,812 - BERTopic - Transformed documents to Embeddings
# 2023-02-01 22:30:53,626 - BERTopic - Reduced dimensionality
# 2023-02-01 22:31:13,033 - BERTopic - Clustered reduced embeddings

# %%
# save model 3
topic_model_3.save("PublicRecords_Model3")

# %%
# most frequent topics: model 3
freq = topic_model_3.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                     Name
# 0      -1   2390                         -1_the_and_in_of
# 1       0    194                  0_paid_bill_taxes_bills
# 2       1    120              1_emails_mayor_january_2018
# 3       2    104                2_public_fees_act_records
# 4       3     97          3_footage_accident_video_camera
# 5       4     96           4_hearing_audio_case_recording
# 6       5     95        5_incident_initial_view_nashville
# 7       6     90                    6_paid_taxes_years_la
# 8       7     72          7_permit_permits_seasons_issued
# 9       8     69           8_body_footage_camera_accident
# 10      9     61                9_send_immovable_post_pre
# 11     10     56              10_911_audio_call_calltaker
# 12     11     55    11_employees_employee_overtime_salary
# 13     12     55        12_occurred_involving_fire_report
# 14     13     54        13_rfp_design_selection_proposals
# 15     14     53           14_homicide_crime_death_murder
# 16     15     52             15_fire_report_copy_incident
# 17     16     50                16_909_street_plans_built
# 18     17     50  17_signal_traffic_intersection_sequence
# 19     18     50            18_fire_incident_report_450am

# %%
topic_model_3.get_topic(0) # get the most frequent topic
# Out:
# [('paid', 0.038555903393578506),
#  ('bill', 0.029223942826505412),
#  ('taxes', 0.024707571325578076),
#  ('bills', 0.02294827303283494),
#  ('tax', 0.021339751692645938)]

# %%
topic_model_3.get_topic(1) # get the 2nd most frequent topic
# Out:
# [('emails', 0.023725011435239914),
#  ('mayor', 0.017533832234769457),
#  ('january', 0.01639388160677135),
#  ('2018', 0.014321792646873692),
#  ('between', 0.01353683132310757)]

# %%
# Set labels for top 10 topics
topic_model_3.set_topic_labels({0: "Tax Payment", 1: "Contracts",
                                2: "Permit Applications", 3: "Body Camera Footage", 4: "Traffic Camera Footage",
                                5: "Permits", 6: "Incident Reports", 7: "Emails",
                                8: "Public Records", 9: "Tax Bills"})

# Display model 3 bar chart
topic_model_3.visualize_barchart(top_n_topics=10, title='Model 3: Topic Word Scores',
                                 custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ae58563d-4496-40f4-8455-30ed6ec295b9" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae58563d-4496-40f4-8455-30ed6ec295b9")) {                    Plotly.newPlot(                        "ae58563d-4496-40f4-8455-30ed6ec295b9",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.021339751692645938,0.02294827303283494,0.024707571325578076,0.029223942826505412,0.038555903393578506],"y":["tax  ","bills  ","taxes  ","bill  ","paid  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.01353683132310757,0.014321792646873692,0.01639388160677135,0.017533832234769457,0.023725011435239914],"y":["between  ","2018  ","january  ","mayor  ","emails  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.006390912212109076,0.006650574945269544,0.007059334889955699,0.007793357343475139,0.008966910556962991],"y":["request  ","records  ","act  ","fees  ","public  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.023850284184297077,0.024749997866552173,0.024844046025309454,0.02679221762482552,0.02738917362468051],"y":["intersection  ","camera  ","video  ","accident  ","footage  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.012466316838833017,0.0175320000019039,0.01989646532289802,0.0201946632567215,0.05024936779260611],"y":["2018  ","recording  ","case  ","audio  ","hearing  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.025747793548865316,0.02605105218648276,0.027963475280528588,0.049512863027513385,0.058880739714325246],"y":["report  ","nashville  ","view  ","initial  ","incident  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.013246159540444733,0.014894524235955709,0.01924884444944765,0.020935281097780412,0.02673149870889815],"y":["property  ","la  ","years  ","taxes  ","paid  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.014350143200509875,0.014436607595275205,0.016048366092066762,0.03258654753763808,0.03680814738817738],"y":["applications  ","issued  ","seasons  ","permits  ","permit  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.026632064293401425,0.030233718203859807,0.03327322891384667,0.03937437404373733,0.052730133575510194],"y":["worn  ","accident  ","camera  ","footage  ","body  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.03455180038994875,0.03939683425111267,0.0414872758142821,0.048265299303265126,0.04875003698047772],"y":["entity  ","pre  ","post  ","immovable  ","send  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks" ...

# %% [markdown]
# Some recurring themes: **Taxes, Body Camera Footage, Traffic Camera Footage.**

# %% [markdown]
# We will now train a 4th model by manipulating the diversity parameter, which controls the similarity of words included in each topic to reduce redundancies. The diversity value ranges from 0 to 1, with 0 being not at all diverse and 1 being very diverse. The default value is 0; by changing this to 0.5 we will diversify the resulting topic representations.

# %%
# train new model, add diversity
topic_model_4 = BERTopic(language="english", calculate_probabilities=True, diversity=0.5, verbose=True)
topics, probs = topic_model_4.fit_transform(requests)
# Out:
# Batches:   0%|          | 0/242 [00:00<?, ?it/s]
# 2023-02-01 22:38:26,238 - BERTopic - Transformed documents to Embeddings
# 2023-02-01 22:38:41,213 - BERTopic - Reduced dimensionality
# 2023-02-01 22:38:47,148 - BERTopic - Clustered reduced embeddings

# %%
# save model 4
topic_model_4.save("PublicRecords_Model4")

# %%
# most frequent topics: model 4
freq = topic_model_4.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                      Name
# 0      -1   2519             -1_orleans_records_request_by
# 1       0    348                   0_taxes_bills_need_nola
# 2       1    134   1_intersection_accident_traffic_cameras
# 3       2    132         2_rfp_proposals_evaluation_sheets
# 4       3    128           3_public_records_fees_louisiana
# 5       4    128  4_hearing_administrative_rental_nicholls
# 6       5     98                   5_fire_nola_occurred_st
# 7       6     88       6_contract_orleans_latg_cooperative
# 8       7     85     7_incident_reports_supplemental_marta
# 9       8     82              8_street_909_orleans_records
# 10      9     78              9_footage_cam_dash_insurance
# 11     10     73            10_fire_requesting_orleans_rpt
# 12     11     72      11_permits_applications_llc_mcdonnel
# 13     12     70                12_911_audio_calls_seconds
# 14     13     69        13_unit_tabulations_group_formally
# 15     14     67           14_emails_january_received_nbsp
# 16     15     64   15_intersection_signals_lanes_claiborne
# 17     16     63          16_public_nopd_requested_records
# 18     17     62             17_nofd_fire_vehicle_occurred
# 19     18     61             18_homicide_scene_im_incident

# %% [markdown]
# The two most frequent topics are again related to taxes and fire incidents.

# %%
topic_model_4.get_topic(0) # get the most frequent topic
# Out:
# [('taxes', 0.029493260865800692),
#  ('bills', 0.0182640595919983),
#  ('need', 0.01567904743967525),
#  ('nola', 0.013872126770303448),
#  ('estate', 0.012537197034205732),
#  ('payments', 0.011365703144392093),
#  ('year', 0.010283969768400068),
#  ('street', 0.007600506969853269),
#  ('amounts', 0.006947649991270705),
#  ('orleans', 0.006433146658354989)]

# %%
topic_model_4.get_topic(1) # get the 2nd most frequent topic
# Out:
# [('intersection', 0.03066384515936059),
#  ('accident', 0.029311217713783675),
#  ('traffic', 0.01846210154101969),
#  ('cameras', 0.015972095592519487),
#  ('crime', 0.01518886538851318),
#  ('cab', 0.010679560083864894),
#  ('claiborne', 0.008913838844011143),
#  ('toyota', 0.008615263110257844),
#  ('2019', 0.008539608784821738),
#  ('street', 0.007435366410932684)]

# %%
# Set labels for top 10 topics
topic_model_4.set_topic_labels({0: "Tax Bills", 1: "Fire Incident",
                                2: "Crime, Traffic Cameras", 3: "RFP", 4: "Public Records",
                                5: "City Court", 6: "Fire Incident", 7: "Proposals",
                                8: "Donations", 9: "Incident Reports"})

# Display model 4 bar chart
topic_model_4.visualize_barchart(top_n_topics=10, title='Model 4: Topic Word Scores',
                                 custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e8ad396a-0e4e-44d0-b3b2-155886e27f51" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8ad396a-0e4e-44d0-b3b2-155886e27f51")) {                    Plotly.newPlot(                        "e8ad396a-0e4e-44d0-b3b2-155886e27f51",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.012537197034205732,0.013872126770303448,0.01567904743967525,0.0182640595919983,0.029493260865800692],"y":["estate  ","nola  ","need  ","bills  ","taxes  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.01518886538851318,0.015972095592519487,0.01846210154101969,0.029311217713783675,0.03066384515936059],"y":["crime  ","cameras  ","traffic  ","accident  ","intersection  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.017092298906328317,0.018385784514160144,0.022385592485299675,0.030978198461131954,0.055797520616323995],"y":["submitted  ","sheets  ","evaluation  ","proposals  ","rfp  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.006991746167608671,0.0072866498412066,0.009111407607878017,0.01029472649423663,0.0130676453020583],"y":["seq  ","louisiana  ","fees  ","records  ","public  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.010539351842528511,0.011953350392791443,0.013227548344164074,0.01579228357946336,0.06304695667518982],"y":["recordings  ","nicholls  ","rental  ","administrative  ","hearing  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.012854087309657333,0.020154997703606434,0.02100899083896445,0.02113194622850057,0.0880080981759066],"y":["number  ","st  ","occurred  ","nola  ","fire  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.008896780968660362,0.010682661227259358,0.011328452502166237,0.011526837086137706,0.03219063566857505],"y":["tpas  ","cooperative  ","latg  ","orleans  ","contract  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01120910401973599,0.014345559118132262,0.018952011111332077,0.021468513882754683,0.09667844724425345],"y":["e3481516  ","marta  ","supplemental  ","reports  ","incident  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.013026197020793313,0.013261806534445334,0.013704397199743104,0.015124368512626735,0.02169230697659051],"y":["plans  ","records  ","orleans  ","909  ","street  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.015372656238080774,0.017002780935646986,0.02215147649976018,0.02539130893807738,0.0465369116501122],"y":["represents  ","insurance  ","dash  ","cam  ","footage  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{ ...

# %% [markdown]
# Now that we've determined several frequent topics based on the results of our 4 models, let's look back at the public records requests and see what people were actually asking for when these topics were mentioned. Shown below are a few requests relating to each of the following topics: traffic cameras, fire incidents, taxes, and body camera footage. Many of these requests are irrelevant or difficult to understand, but there are many that provide some good insight!

# %%
traffic = [x for x in requests if 'traffic' in x and 'camera' in x]
for i in traffic[:5]: print(i, '\n')
# Out:
# On October 11, 2016 my bank account was charged $331. It was paid to "PAM New Orleans". I was told at first it had to do with a parking violation; later, that was changed to be a traffic camera "violation". I would like access to the file that describes who received the $331 and what it was for. Specifically and particularly I need to determine whether that $331 fully paid alleged violations on 6-23-16 and 9-6-16
#
# I'm requesting the amount of money that’s been generated by the traffic cameras for the New Orleans Police department and other city-run departments for the past four years. Also, I'm requesting the number of tickets issued for the past four using the traffic camera and the amount of tickets that are still outstanding.
#  Thank you,
#
# To Whom it May Concern:
#  We are a local community small business specializing in digital solutions for New Orleanians. As part of the growing Tech industry, we are always in need of high quality data. In particular, our project needs data for the GPS coordinates for Orleans Parish traffic cameras (speeding and red light). Our team has already assembled a list of locations (according to intersections and major landmarks).  Please accept our information request and make the GPS coordinates of traffic cameras available. This will enable us to reference your authoritative and high quality data as our continuing source of information for our Tech projects.
#
# I'd like a copy of all the letters sent to the city of New Orleans/Mayor Mitch Landrieu's office where citizens requested traffic cameras be placed at a certain location.
#
# This request is for traffic camera footage near the intersection of St. Charles and Sixth Street. An automobile accident occurred near this intersection on August 26, 2016 at approximately 8:00 p.m. &nbsp;I ask that you please forward the security footage from 5:00 p.m. through 8:30 p.m. on August 26, 2016 to my office without delay.

# %%
fire = [x for x in requests if 'fire' in x and 'incident' in x]
for i in fire[:3]: print(i, '\n')
# Out:
# Subject:&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Freedom of Information Act (FOIA) Request/File Review Request
#  Royal St. Charles Hotel
#  135 St. Charles Avenue, New Orleans, LA
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Parcel ID#: 036
#  AEI Project No. 373982
#  &nbsp;
#  To whom it may concern:
#  &nbsp;
#  Please accept this as request for any information/documentation/files with your department regarding the above-referenced property.
#  &nbsp;
#  AEI Consultants is currently conducting the Phase I Environmental Site Assessment for the property. The ASTM Practice E1527-13 Standard Practice of Environmental Site Assessments requires that a records search be conducted with local regulatory departments for information regarding the subject property. Of particular interest are the following items:
#  &nbsp;
#
#  Records regarding hazardous materials usage/storage/incidents or known environmental concerns/contamination which may have affected the property,
#  Records regarding aboveground or underground storage tank (UST) systems, which are currently or historically located at the property.
#  Records of fire inspections at the subject property.
#
#  &nbsp;
# Please call (954-560-7365) or email (abenedict@aeiconsultants.com) me to discuss the file information or if you require further information. Thank you for your time and attention regarding this matter.
#
# Leaaf Environmental, LLC is performing a Phase I Environmental Site Assessment for the property located at 8181 Lake Forest Blvd, New Orleans, LA 70126. Please include any information or records pertaining to fire responses, reported releases, or environmental incidents or inspections at this address. Thank you,&nbsp;  Kelly Caris&nbsp;
#
# Leaaf Environmental, LLC is performing a Phase I Environmental Site Assessment for the property located at&nbsp;1626 Oretha C. Haley Blvd., New Orleans, LA 70113.&nbsp;Please include any information or records pertaining to fire responses, reported releases, or environmental incidents or inspections at this address.&nbsp;

# %%
taxes = [x for x in requests if 'tax' in x and 'bill' in x]
for i in taxes[:3]: print(i, '\n')
# Out:
# Please send me a copy of all pre and post tax sale notices issued in connection with the 2012 tax sale of 4222-4224 Willow Street and any attempts to notify the&nbsp;property owners of&nbsp;the related&nbsp;2011 tax delinquency. Tax bill number is 614336108.
#
# Please provide the following:
#
#  Copies of any and all pre and post-tax sale notice provided to any person or entity whatsoever regarding the 2007 tax sale of the property at the municipal address 2724 Fourth (4th) Street, Tax Bill No. 412305008 to Sabrina S. Hankton for unpaid 2005 ad valorem taxes as well as any documentation regarding confirmation of receipt of said pre and post-tax sale notices by any person or entity whatsoever regarding the 2007 tax sale of the property at the municipal address 2724 Fourth (4th) Street, Tax Bill No. 412305008 to Sabrina S. Hankton for unpaid 2005 ad valorem taxes.
#
#
#  Copies of any and all documents regarding any and all requests for redemption/payoff of the 2007 tax sale of the property at the municipal address 2724 Fourth (4th) Street, Tax Bill No. 412305008 to Sabrina S. Hankton for unpaid 2005 ad valorem taxes.
#
#
#  Copies of any itemized log or report of the City of New Orleans Department of Finance and/or its hired agencies of all electronic, facsimile and/or telephone communications, whether successful or failed, whether answered or unanswered, to any person(s) in any way related to the collection and/or sale of the ad valorem taxes assessed and billed for the property at Tax Bill No. 412305008 irrespective of the purpose of said communication.&nbsp; Where possible, the above request shall include a transcript of the details and content of any such communications, whether unilateral or otherwise.
#
# Please forward a copy of&nbsp;the following:
#
#  Any and all pre and post-tax sale notice provided to any person or entity whatsoever regarding the 2008 tax sale of Tax Bill No. 39W051833, 7921 Branch Drive, New Orleans, Louisiana to Ida Warfield&nbsp;for unpaid 2005, 2006, &amp; 2007&nbsp;ad valorem taxes as well as any documentation regarding confirmation of receipt of said pre and post-tax sale notices by any person or entity whatsoever ; and
#
#  &nbsp;
#
#  Any and all documents regarding any and all requests for redemption/payoff of the 2008 tax sale of Tax Bill No. 39W051833, 7921 Branch Drive, New Orleans, Louisiana to Ida Warfield&nbsp;for unpaid 2005, 2006, &amp; 2007&nbsp; ad valorem taxes; and
#
#  &nbsp;
#
#  An itemized log or report of the City of New Orleans Department of Finance and/or its hired agencies of all electronic, facsimile and/or telephone communications, whether successful or failed, whether answered or unanswered, to Mr &amp; Mrs Patrick Kelly&nbsp;in any way related to the collection and/or sale of the ad valorem taxes assessed and billed for the property at Tax Bill No. 39W051833, 7921 Branch Drive, New Orleans, Louisiana, irrespective of the purpose of said communication.&nbsp; Where possible, the above request shall include a transcript of the details and content of any such communications, whether unilateral or otherwise.

# %%
body_cam = [x for x in requests if 'body' in x and 'camera' in x]
for i in body_cam[:5]: print(i, '\n')
# Out:
# We are filing a public records request for the following information: The responding NOPD officer's body camera video (BWC) from item number: I-16415-16. The incident happened 9/15/2016.&nbsp;&nbsp;
#
# My taxi was broken by somebody during my mechanic was putting some break pads on it. So my bank cards were stolen including my driver license. So I request a camera review toward my car in order to catch the person. I have the police report done and my bank had notified some transactions made!
#
# The Associated Press makes the follow request for information and public records request concerning body worn cameras:
#  **The number of New Orleanspolice officers issued body worn cameras as of July 1, 2016
#  **Total number of New Orleans&nbsp;police officers as of July 1, 2016
#  **A copy of policies or general police orders governing use of police body worn cameras.
#  **Copies of any audits, studies or reports written between Jan. 1, 2015 and July 1, 2016 for compliance rates for officer use of their issued body worn cameras.
#
# Any and all records associated with NOPD item number F0123216, including but not limited to the initial incident report, supplemental reports and any body worn camera footage.
#
# I request any body-worn camera video of the Nov. 4, 2015 arrest of Judah Mason under item number&nbsp;K-3771-15 for on-site inspection. Mason pleaded guilty in connection with this incident on March 31, 2016.

# %% [markdown]
# While sifting through some of the public records requests, we came across some interesting information/requests relating to traffic cameras. The following requests were made:

# %% [markdown]
# "I am requesting the demographic breakdowns – race, age, sex -- of all people issued traffic tickets by NOPD officers in 2016, 2017, 2018 and 2019.
# I would also like the total number of tickets issued and the total dollar amount of those tickets."
#
# "I am requesting the demographic breakdowns – race, age, sex -- of all people issued traffic tickets by automated traffic cameras in 2016, 2017, 2018 and 2019.
# I would also like the total number of tickets issued and the total dollar amount of those tickets."
#
# "Our project needs data for the GPS coordinates for Orleans Parish traffic cameras (speeding and red light). Our team has already assembled a list of locations (according to intersections and major landmarks).  Please accept our information request and make the GPS coordinates of traffic cameras available. This will enable us to reference your authoritative and high quality data as our continuing source of information for our Tech projects."

# %% [markdown]
# These are some interesting data requests that could possibly be displayed in a dashboard!

# %% [markdown]
# ### **Search Feedback**

# %% [markdown]
# Below, we import the Search Feedback dataset, which includes the date, search term used, and desired search term. From this data, we can see why users are searching the site, and what they hoped to find.

# %%
search = pd.read_excel('Search Feedback.xlsx',skiprows=2)

# %%
search.head()
# Out:
#             Submitted              Search Term Used  \
# 0 2022-10-16 21:13:10                   Court times
# 1 2022-10-16 17:55:03  Calucem and Cementos Mullins
# 2 2022-10-16 14:05:19        Sewerage & Water Board
# 3 2022-10-15 19:03:57                     Fireworks
# 4 2022-10-15 17:32:45      Check old liquor license
#
#                                       Desired Result  \
# 0                                        Court times
# 1  The address for the new calucem plant in New O...
# 2            how to report water leaking into street
# 3             Fireworks display dates in New Orleans
# 4  Old records from 1973\nFor mousetrap Bar and C...
#
#                          Email
# 0  Darnellwalker1201@gmail.com
# 1       vmportermspr@yahoo.com
# 2           luckybean@juno.com
# 3         randycadle@gmail.com
# 4   watercrestcondos@gmail.com

# %%
search["Search Term Used"].value_counts()
# Out:
# BIRTH CERTIFICATE                             42
# permit                                        29
# permits                                       24
# Police report                                 24
# ADDRESS                                       24
#                                               ..
# Do I have a photo ticket                       1
# Bid Number                                     1
# delinquent occupational license #100472848     1
# STR license renewal                            1
# second line permits                            1
# Name: Search Term Used, Length: 4026, dtype: int64

# %%
search["Desired Result"].value_counts()
# Out:
# permit                                                           45
# Application                                                      31
# police report                                                    23
# nothing                                                          23
# permits                                                          21
#                                                                  ..
# A bin or can for recycling                                        1
# CDL classes                                                       1
# free home repairs or assistance with home repairs for elderly     1
# cancelled or not for 8/24/2020                                    1
# application forms                                                 1
# Name: Desired Result, Length: 4320, dtype: int64

# %% [markdown]
# Below, NaN values were dropped from the DataFrame in order to use the .contains() method to find any search term that used certain keywords, particularly "permits" and "police".

# %%
df = search.dropna()
find_all_permit = df.loc[df['Search Term Used'].str.contains("permit|permits", case=False)]
find_all_permit['Search Term Used'].count()
# Out:
# 486

# %%
find_all_permit = df.loc[df['Search Term Used'].str.contains("police reports|police report", case=False)]
find_all_permit['Search Term Used'].count()
# Out:
# 45

# %%
find_all_permit = df.loc[df['Search Term Used'].str.contains("police|NOPD", case=False)]
find_all_permit['Search Term Used'].count()
# Out:
# 90

# %%
find_all_permit = df.loc[df['Desired Result'].str.contains("permit|permits", case=False)]
find_all_permit['Desired Result'].count()
# Out:
# 663

# %%
find_all_permit = df.loc[df['Desired Result'].str.contains("police reports|police report", case=False)]
find_all_permit['Desired Result'].count()
# Out:
# 61

# %%
find_all_permit = df.loc[df['Desired Result'].str.contains("police|NOPD", case=False)]
find_all_permit['Desired Result'].count()
# Out:
# 109

# %% [markdown]
# Many search terms and desired results had to do with permits, police reports, and NOPD. This indicates that a dashboard displaying these types of data could be very benefical and useful for the NOLA community.

# %% [markdown]
# # **Was This Page Helpful.xlsx**

# %% [markdown]
# Section completed by Max Motz

# %% [markdown]
# This section analyzes and makes observations from the "Was This Page Helpful.xlsx" dataset provided by the people at datadriven.nola.gov.

# %% [markdown]
# "Was This Page Helpful.xlsx" is a spreadsheet containing user submitted responses to the prompt "Was this Page Helpful?" Occasionally when searching through pages on the site, users will be prompted to give feedback. They make a binary choice of whether the site was helpful or not and can elaborate in a feedback text bubble.

# %%
# Install necessary libraries
# %%capture
# !pip install bertopic
import pandas as pd
import spacy
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer


#from umap import UMAP
#umap_model = UMAP(random_state=42)
#topic_model = BERTopic(umap_model=umap_model)

# %%
# Feedback on Website
#May need to point directory at proper file path depending on load context

feedbackpd = pd.read_excel('Was This Page Helpful?.xlsx',skiprows=2)
feedback = feedbackpd['Feedback'].tolist()
feedback = [str(i) for i in feedback]

feedbackpd.iloc[:10]
# Out:
#                 Submitted Helpful? Section  \
# 0 2022-10-16 21:18:37.410       No    NEXT
# 1 2022-10-16 19:57:10.650       No    NEXT
# 2 2022-10-16 18:58:16.753       No    NEXT
# 3 2022-10-16 18:47:15.947       No    NEXT
# 4 2022-10-16 16:26:50.943      Yes    NEXT
# 5 2022-10-16 10:17:11.963       No    NEXT
# 6 2022-10-15 18:30:42.030       No    NEXT
# 7 2022-10-15 15:08:24.820       No    NEXT
# 8 2022-10-15 15:05:42.180       No    NEXT
# 9 2022-10-15 12:38:11.553       No    NEXT
#
#                                                  URL  \
# 0                              /NEXT/Sanitation/Home
# 1                                /NEXT/Services/Home
# 2  /NEXT/Services/Trash-and-Recycling/Schedule/Lo...
# 3  /NEXT/Services/Traffic-Transportation/Traffic-...
# 4  /NEXT/Services/Trash-and-Recycling/Recycling/P...
# 5  /NEXT/Services/Traffic-Transportation/Traffic-...
# 6  /NEXT/Services/Parking/Meters/Parking-Meter-Ho...
# 7  /NEXT/Services/Traffic-Transportation/Traffic-...
# 8  /NEXT/Services/Streets-Construction/Street-Lig...
# 9                              /NEXT/Sanitation/Home
#
#                                             Feedback  \
# 0  Our trash can went missing and we need to know...
# 1  I’m trying to figure out how to report food po...
# 2  Doesn't accept my address. "loading" forever. ...
# 3  I need to make a partial payment and don't any...
# 4  It would be helpful to know if you can bring s...
# 5  The old system was so much easier and user fri...
# 6                       Let me enter zone number plz
# 7  Finding lost tickets should be a service offer...
# 8  unable to use the online site to report street...
# 9                   How to find our trash collector.
#
#                              Mailto
# 0  web_feedback_sanitation@nola.gov
# 1                 epogburn@nola.gov
# 2  web_feedback_sanitation@nola.gov
# 3         web_feedback_DPW@nola.gov
# 4                 epogburn@nola.gov
# 5         web_feedback_DPW@nola.gov
# 6         web_feedback_DPW@nola.gov
# 7         web_feedback_DPW@nola.gov
# 8         web_feedback_DPW@nola.gov
# 9  web_feedback_sanitation@nola.gov

# %% [markdown]
# Variables are as follows:
#
# *   **Submitted:** datetime64 type variable that explays the exact date and time the prompt was submitted by the user.
#
# *   **Helpful?:** Categorical variable from the users binary decision about whether the page was helpgul to them or not.
#
# *   **Section:** Categorical variable detailing the part of the site the prompt was filled out on.
#
# *   **URL:** String detailing the exact location the prompt was filled out.
#
# *   **Feedback:** String input by user detailing what feedback they have with the site.

# %% [markdown]
# **Categorical Variable Analysis**

# %%
display(feedbackpd["Helpful?"].value_counts())
feedbackpd["Helpful?"].value_counts().plot.pie(y='mass', figsize=(10, 10))
# Out:
# No     6961
# Yes    4005
# Name: Helpful?, dtype: int64

# %%
display("No Percentage")
display(6961/(6961+4005)*100)
display("Yes Percentage")
display(4005/(6961+4005)*100)
# Out:
# 'No Percentage'
# 63.47802298012037
# 'Yes Percentage'
# 36.52197701987963

# %% [markdown]
# Almost two thirds of the feedback recieved from the feedback prompt is negative. This is could be due to users being more inclined to provide criticism than praise as praise requires no issues to be fixed.

# %% [markdown]
# The following code finds the sections that had the most negative feedback:

# %%
Nodb = feedbackpd.loc[feedbackpd["Helpful?"] == "No"]
Nodb["Section"].value_counts()
Nodb["Section"].value_counts().loc[Nodb["Section"].value_counts() >= 100].plot.bar(y='mass', figsize=(10, 10))

# %% [markdown]
# *Contact Us* Is likely mostly negative as communication with the city is slow. It is also used as an extra way to ask the people at the city to respond and get in contact with individuals. Here is an example of that:

# %%
CU = feedbackpd[feedbackpd["Section"] == "Contact-Us"].iloc[1:2]
CU["Feedback"][152]
# Out:
# "I've been came to y'all for help since 2019 y'all did help me with rental assistance and see if y'all repeat the utility bills they never got paid cuz someone please give me a call I'm trying to reach out for help thank you and have a blessed day.   Rochelle Davis"

# %% [markdown]
# *OneStop* Is likely referring to https://onestopapp.nola.gov/, a government site used for applying for permits and licenses. It is in beta, which likely contributes to its glitchy nature as implied by comments. Here is an example a criticism of it:

# %%
OS = feedbackpd[feedbackpd["Section"] == "OneStop"].iloc[2:3]
OS["Feedback"][207]
# Out:
# 'Does not give 1/2 the info needed to submit for a permit. This city is so fucking stupid across the board. Not a god damn thing works well here. No one changes shit. No one gives a shit. Fuck it all'

# %% [markdown]
# *Pay-Tickets* is negative because people will respond to the prompt if they have trouble paying tickets.

# %%
PT = feedbackpd[feedbackpd["Section"] == "Pay-Tickets"].iloc[0:1]
PT["Feedback"][147]
# Out:
# 'You need to send confirmation that online contestations for tickets were received. I submitted my contestation, but did not receive any confirmation afterwards. The last time this happened, I was told my online submission was never received and had to work with your office to reverse additional charges.\n\nPlease let me know if you received my contestation for Parking Violation 620819286'

# %% [markdown]
# So most the major feedback hubs are used by users to voice complaints with the government rather than the site. *Search* and other site centric sections may help us more with site issues.

# %%
s = Nodb[feedbackpd["Section"] == "Search"].iloc[:10]
s["Feedback"]
# Out:
# 105        Trying to search Orleans One Stop, not Google
# 135                                              Not yet
# 253    I WANT MY TRADH PICKED UP!\nI PAY MONTHLY ON T...
# 466                               I don't have an answer
# 722    Could not find my application for renewal of m...
# 784    need instruction on how to find rules pertaini...
# 818    Seeking Information On capital projects for th...
# 819                 Did not respond with the information
# 829    I am trying to find out when a ABO PERMIT IS N...
# 922    It does not have good information available on...
# Name: Feedback, dtype: object

# %% [markdown]
# Looking at the first ten, it seems to be a mixed bag of complaints. A lot are still complaints directed at city processes. Some, like 922, are ambiguous. However, some cite specific sources of information users want to access. However it is hard to tie these together with a centralized theme.

# %% [markdown]
# **Conclusion:** Many users fill out the prompt to voice complaints they have with the city government rather than genuine feedback for the site. Still, individual feedback specifically identified being related to the site and certain sections less related to government may provide useful.

# %% [markdown]
# **Was This Page Helpful.xlsx NLP**

# %% [markdown]
# Re-worked code from PublicRecords_NLP.ipynb to run NLP on site feedback data. Bertopic has an element of simulated randomness which can mess around with the order of topics as presented. Please refrain from re-running poriton of code.

# %% [markdown]
# Includes all prompts, yes and no, from the dataset to find what people that respond to the prompt are inquiring about.

# %%
# Install necessary libraries
# %%capture
# !pip install bertopic
import pandas as pd
import spacy
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Feedback on Website
#May need to point directory at proper file path depending on load context
feedback = pd.read_excel('Was This Page Helpful?.xlsx',skiprows=2)
feedback = feedback['Feedback'].tolist()
feedback = [str(i) for i in feedback]

# %%
# training
topic_model_1 = BERTopic(language="english", calculate_probabilities=True, verbose=True)
topics, probs = topic_model_1.fit_transform(feedback)
# Out:
# Batches:   0%|          | 0/343 [00:00<?, ?it/s]
# 2023-02-01 22:46:50,185 - BERTopic - Transformed documents to Embeddings
# 2023-02-01 22:47:01,867 - BERTopic - Reduced dimensionality
# 2023-02-01 22:47:21,507 - BERTopic - Clustered reduced embeddings

# %%
# save model 1
topic_model_1.save("Site Feedback")
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/sparse/_index.py:125: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.

# %%
# most frequent topics: -1 indicates outliers, ignore
freq = topic_model_1.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                     Name
# 0      -1   3057                         -1_the_in_and_to
# 1       0    316            0_tax_taxes_sales_inheritance
# 2       1    223         1_permit_permits_building_status
# 3       2    166           2_saints_orleans_new_retrieved
# 4       3    152               3_map_maps_district_zoning
# 5       4    148          4_report_police_accident_stolen
# 6       5    133      5_recycling_recycle_hazardous_glass
# 7       6    125  6_monuments_history_statues_confederate
# 8       7    108             7_nola_nolagov_testing_links
# 9       8    102             8_volatility_hedge_roi_index
# 10      9    100  9_staff_department_departments_director
# 11     10     96           10_rental_rent_assistance_help
# 12     11     95          11_address_lookup_change_street
# 13     12     95             12_updated_update_last_needs
# 14     13     94              13_parking_uhaul_signs_park
# 15     14     91          14_email_address_addresses_send
# 16     15     89    15_occupational_license_renew_renewal
# 17     16     86       16_helpful_very_helpfull_helpfully
# 18     17     85             17_trash_pick_pickup_garbage
# 19     18     83                 18_311_phone_number_call

# %%
topic_model_1.get_topic(0) # get the most frequent topic
# Out:
# [('tax', 0.05204529066518111),
#  ('taxes', 0.027614016864175753),
#  ('sales', 0.019772832548970304),
#  ('inheritance', 0.019476439648762934),
#  ('property', 0.018668631119442763),
#  ('pay', 0.015481648475265107),
#  ('estate', 0.015117782098690831),
#  ('rolls', 0.012714483200762038),
#  ('bill', 0.012614144617471908),
#  ('2020', 0.009575198788782465)]

# %%
topic_model_1.get_topic(1) # get the 2nd most frequent topic
# Out:
# [('permit', 0.06616865000452404),
#  ('permits', 0.030629929835493255),
#  ('building', 0.011858699981187064),
#  ('status', 0.009448946801871869),
#  ('find', 0.009367127756536505),
#  ('how', 0.008723760059027315),
#  ('for', 0.008709311753511),
#  ('need', 0.008226646815342829),
#  ('can', 0.008106162854314888),
#  ('trying', 0.008019441188961935)]

# %%
# size of each circle = frequency of topic
interactive_map = topic_model_1.visualize_topics(); interactive_map
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a0f52213-eecb-49f2-85b7-a0f39a7f003f" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0f52213-eecb-49f2-85b7-a0f39a7f003f")) {                    Plotly.newPlot(                        "a0f52213-eecb-49f2-85b7-a0f39a7f003f",                        [{"customdata":[[0,"tax | taxes | sales | inheritance | property",316],[1,"permit | permits | building | status | find",223],[2,"saints | orleans | new | retrieved | up",166],[3,"map | maps | district | zoning | names",152],[4,"report | police | accident | stolen | file",148],[5,"recycling | recycle | hazardous | glass | waste",133],[6,"monuments | history | statues | confederate | removing",125],[7,"nola | nolagov | testing | links | red",108],[8,"volatility | hedge | roi | index | gdp",102],[9,"staff | department | departments | director | names",100],[10,"rental | rent | assistance | help | eviction",96],[11,"address | lookup | change | street | different",95],[12,"updated | update | last | needs | 2014",95],[13,"parking | uhaul | signs | park | handicapped",94],[14,"email | address | addresses | send | contact",91],[15,"occupational | license | renew | renewal | renewing",89],[16,"helpful | very | helpfull | helpfully | reminder",86],[17,"trash | pick | pickup | garbage | collection",85],[18,"311 | phone | number | call | dial",83],[19,"meeting | meetings | calendar | vcc | agendas",80],[20,"page | easy | navigate | helpful | was",79],[21,"job | jobs | employment | looking | resume",77],[22,"parking | ticket | pay | tickets | system",73],[23,"court | date | case | clerks | judge",70],[24,"voting | ballot | vote | early | election",65],[25,"ticket | pay | seatbelt | online | system",61],[26,"payment | pay | swb | online | make",60],[27,"de | que | la | el | en",60],[28,"summer | youth | apply | appointment | program",59],[29,"ticket | tickets | number | lost | owe",57],[30,"application | apply | applications | status | program",56],[31,"nopd | nofd | officer | detail | nopds",53],[32,"thanks | yass | nicely | nice | laid",53],[33,"mayor | she | her | city | cantrell",53],[34,"wheat | starch | yes | helpful | starc",52],[35,"hours | hall | open | operation | school",52],[36,"residential | parking | permit | activate | visitor",49],[37,"plate | license | number | ticket | enter",46],[38,"property | properties | auction | granted | deed",46],[39,"blank | page | scroll | empty | tab",46],[40,"application | easy | process | fill | quick",45],[41,"thank | you | uhuru | boykins | kindly",45],[42,"brake | tag | tags | stations | locations",44],[43,"help | assistance | helping | thank | thanks",44],[44,"crime | map | they | apartment | meat",43],[45,"williams | trina | louisiana | isaac | jr",43],[46,"thankful | god | blessing | thanks | bless",43],[47,"phone | number | numbers | ring | contacs",42],[48,"white | privileged | racist | statement | nigger",42],[49,"great | fabulous | yay | perfect | wonderful",41],[50,"license | str | licenses | business | licence",40],[51,"closures | closed | parade | routes | road",40],[52,"yes | absolutely | yeah | docket | course",39],[53,"good | lul | httpswwwyoutubecomwatchve1qdjbpiqv0 | haveinfo | thankfully",39],[54,"bill | water | bills | help | assistance",39],[55,"job | good | great | keep | work",38],[56,"links | work | link | bottom | dont",37],[57,"light | lights | streetlight | report | street",37],[58,"blighted | blight | property | properties | houses",36],[59,"helpful | very | was | it | its",36],[60,"contact | contacts | info | no | information",36],[61,"covid | positive | pandemic | peso | test",36],[62,"term | short | rentals | rental | illegal",35],[63,"request | honored | requestors | submit | rejected",35],[64,"hearing | hearings | virtual |  ...

# %%
# Set labels for top 10 topics
topic_model_1.set_topic_labels({0: "Taxes", 1: "Trash and Recycling",
                                2: "Easy Application Process", 3: "Emails", 4: "Location Data",
                                5: "Police Report", 6: "Ticket Payments", 7: "Needs Update",
                                8: "Monument Removal", 9: "Easy Page Navigation"})

# Display model 1 bar chart
topic_model_1.visualize_barchart(top_n_topics=10, title='Model 1: Topic Word Scores',
                                 custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9e85691e-8af8-4e6a-825a-783f93badeea" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e85691e-8af8-4e6a-825a-783f93badeea")) {                    Plotly.newPlot(                        "9e85691e-8af8-4e6a-825a-783f93badeea",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.018456244377285824,0.01877661965370169,0.018971400950171514,0.026783154282595076,0.050199305159967546],"y":["inheritance  ","sales  ","property  ","taxes  ","tax  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.018239588169170335,0.018285225919266734,0.019263657385025203,0.03747018069131202,0.040353702914277645],"y":["garbage  ","pick  ","pickup  ","recycling  ","trash  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.014453949124737854,0.01644009347093542,0.018289240337757046,0.028659736700407692,0.06448950641298791],"y":["assistance  ","process  ","easy  ","apply  ","application  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.018501498895987026,0.02782213137089025,0.04164614715765206,0.05208490016663732,0.08208964647681959],"y":["emails  ","addresses  ","address  ","contact  ","email  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.01791578646352788,0.02298009360917059,0.025656171478322547,0.02780841648430054,0.07601199055985906],"y":["districts  ","district  ","zoning  ","maps  ","map  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.015059505644251096,0.015370123753294534,0.018140889977688153,0.02749458006980428,0.04168902573233592],"y":["incident  ","file  ","accident  ","police  ","report  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.015252293500943068,0.016706783278057566,0.017253361690964954,0.026976659001479598,0.05370230118379849],"y":["system  ","number  ","tickets  ","pay  ","ticket  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.019296246637998844,0.023280428389136958,0.025892754924472627,0.06373025452278915,0.10585197163358899],"y":["dates  ","needs  ","last  ","update  ","updated  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.011983997212738714,0.017843578569044862,0.020526898707086662,0.0216118648512999,0.022685313420116485],"y":["removal  ","confederate  ","statues  ","history  ","monuments  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.017239714114064275,0.018982992980877942,0.02631828743766382,0.026615830326308553,0.036209530051043874],"y":["very  ","navigate  ","easy  ","blog  ","page  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{ ...

# %% [markdown]
# The most frequent topics addressed in the prompts on the site according to model one are as follows:
# 1. Taxes
# 2. Trash
# 3. Easy Application Process
# 4. Emails
# 5. Location Data
# 6. Police Report
# 7. Ticket Payments
# 8. Needed Updates
# 9. Monument Removal
# 10. Easy Page Navigation

# %%
# change ngram_range, let each entity in a topic be up to 3 words
vectorizer_model = CountVectorizer(ngram_range=(1, 3))

# update model 1
topic_model_1.update_topics(feedback, vectorizer_model=vectorizer_model)

# %%
# get most frequent topics: ngram_range = (1,3)
freq = topic_model_1.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                               Name  \
# 0      -1   3057                                   -1_the_to_and_in
# 1       0    316                         0_tax_taxes_property_sales
# 2       1    223                    1_permit_permits_the permit_for
# 3       2    166                   2_orleans_new orleans_new_saints
# 4       3    152                        3_map_the map_maps_district
# 5       4    148             4_report_police report_police_accident
# 6       5    133        5_recycling_recycle_hazardous_the recycling
# 7       6    125            6_history_monuments_statues_confederate
# 8       7    108                     7_nola_nolagov_of nola_in nola
# 9       8    102                       8_volatility_hedge_roi_index
# 10      9    100      9_staff_department_departments_the department
# 11     10     96        10_rental_rental assistance_rent_assistance
# 12     11     95           11_address_my address_lookup_the address
# 13     12     95           12_updated_update_not updated_be updated
# 14     13     94                        13_parking_uhaul_park_signs
# 15     14     91            14_email_email address_address_an email
# 16     15     89  15_license_occupational_occupational license_r...
# 17     16     86  16_helpful very_helpful very helpful_very help...
# 18     17     85                       17_trash_pick_pickup_garbage
# 19     18     83                         18_311_to 311_number_phone
#
#                                CustomName
# 0                        -1_the_in_and_to
# 1                                   Taxes
# 2                     Trash and Recycling
# 3                Easy Application Process
# 4                                  Emails
# 5                           Location Data
# 6                           Police Report
# 7                         Ticket Payments
# 8                            Needs Update
# 9                        Monument Removal
# 10                   Easy Page Navigation
# 11         10_rental_rent_assistance_help
# 12        11_address_lookup_change_street
# 13           12_updated_update_last_needs
# 14            13_parking_uhaul_signs_park
# 15        14_email_address_addresses_send
# 16  15_occupational_license_renew_renewal
# 17     16_helpful_very_helpfull_helpfully
# 18           17_trash_pick_pickup_garbage
# 19               18_311_phone_number_call

# %%
# train a new model with modified topic sizes (min topic size = 5)
topic_model_2 = BERTopic(language="english", min_topic_size=5, calculate_probabilities=True, verbose=True)
topics, probs = topic_model_2.fit_transform(feedback)
# Out:
# Batches:   0%|          | 0/343 [00:00<?, ?it/s]
# 2023-02-01 22:52:11,849 - BERTopic - Transformed documents to Embeddings
# 2023-02-01 22:52:23,528 - BERTopic - Reduced dimensionality
# 2023-02-01 22:53:16,547 - BERTopic - Clustered reduced embeddings

# %%
# save model 2
topic_model_2.save("Site Feedback 2")
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/sparse/_index.py:125: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.

# %%
# most frequent topics: model 2
freq = topic_model_2.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                     Name
# 0      -1   3063                         -1_in_of_and_the
# 1       0    155        0_email_contact_address_addresses
# 2       1    154              1_ticket_pay_tickets_system
# 3       2    126           2_saints_retrieved_orleans_new
# 4       3    123  3_monuments_statues_confederate_history
# 5       4    123       4_permit_permits_status_electrical
# 6       5    104     5_occupational_license_renew_renewal
# 7       6    103                6_nola_nolagov_cnvntn_now
# 8       7     98  7_staff_department_departments_director
# 9       8     86        8_helpful_very_helpfull_helpfully
# 10      9     81           9_address_lookup_street_three3
# 11     10     81             10_updated_update_last_needs
# 12     11     78   11_recycling_recycle_plastics_recycled
# 13     12     71            12_parking_ticket_pay_tickets
# 14     13     69          13_phone_numbers_number_answers
# 15     14     68              14_voting_ballot_vote_early
# 16     15     67         15_report_police_download_stolen
# 17     16     59                          16_de_que_la_el
# 18     17     58       17_inheritance_tax_estate_property
# 19     18     58          18_meeting_meetings_vcc_agendas

# %%
topic_model_2.get_topic(0) # get the most frequent topic
# Out:
# [('email', 0.06176810702144016),
#  ('contact', 0.04338544364393625),
#  ('address', 0.0317882486500169),
#  ('addresses', 0.022129222457505704),
#  ('send', 0.017307204498720478),
#  ('emails', 0.015337293084185818),
#  ('mail', 0.0118119667980982),
#  ('no', 0.011267617989596896),
#  ('gmailcom', 0.010993396080158223),
#  ('an', 0.010563664893636223)]

# %%
topic_model_2.get_topic(1) # get the 2nd most frequent topic
# Out:
# [('ticket', 0.035374789822052465),
#  ('pay', 0.018327759194854843),
#  ('tickets', 0.017373932224605593),
#  ('system', 0.012666635354729132),
#  ('number', 0.01176658442404486),
#  ('seatbelt', 0.010258596528449607),
#  ('online', 0.009519611649652876),
#  ('lost', 0.009072976584947382),
#  ('traffic', 0.008011227806629658),
#  ('unable', 0.006788653568410868)]

# %%
# Set labels for top 10 topics
topic_model_2.set_topic_labels({0: "Emails", 1: "Ticket Payments",
                                2: "Recycling", 3: "Monument Removal", 4: "Permits",
                                5: "Site Problems", 6: "Government Staff Info", 7: "Trash",
                                8: "License Renewal", 9: "Meeting Scheduling"})

# Display model 2 bar chart
topic_model_2.visualize_barchart(top_n_topics=10, title='Model 2: Topic Word Scores',
                                 custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c266bda6-1619-4a15-89be-dfe678f7c545" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c266bda6-1619-4a15-89be-dfe678f7c545")) {                    Plotly.newPlot(                        "c266bda6-1619-4a15-89be-dfe678f7c545",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.015626897566013116,0.022244878881574795,0.028607607741412248,0.039020025785484753,0.054527725079008896],"y":["send  ","addresses  ","address  ","contact  ","email  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.010375101693643932,0.013660472576863222,0.015488413544375008,0.015533266276818862,0.03147025857097084],"y":["number  ","system  ","pay  ","tickets  ","ticket  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.016469981094754314,0.01700119835251737,0.018657035538075004,0.021054983646519587,0.058889158687130794],"y":["waste  ","glass  ","hazardous  ","recycle  ","recycling  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.011082045287128877,0.015594351105101927,0.01625307660253867,0.01783717093088227,0.01947859193275037],"y":["removal  ","confederate  ","history  ","statues  ","monuments  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.008369210302882929,0.009315595038576492,0.013244405011179211,0.029838638289378352,0.05786932715052533],"y":["cut  ","utilityservice  ","status  ","permits  ","permit  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.005959360464708456,0.006686681551725622,0.008475477926390286,0.015628918642726124,0.03933177906707581],"y":["links  ","red  ","testing  ","nolagov  ","nola  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.01898166482980773,0.021343560611358177,0.025231166579821857,0.027754403677132392,0.047101113074579676],"y":["names  ","director  ","departments  ","department  ","staff  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.017833851672618257,0.027441017441892056,0.03217503697287828,0.03444147987798461,0.06970336495639964],"y":["picked  ","garbage  ","pickup  ","pick  ","trash  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.0158173005373845,0.03569002853649003,0.04717895574504754,0.05015616667759302,0.06205828346269013],"y":["renewing  ","renewal  ","renew  ","license  ","occupational  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.0238430163482224,0.03058433541700285,0.04566639494391756,0.04651762451632147,0.08694793592713025],"y":["agendas  ","vcc  ","meetings  ","calendar  ","meeting  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"conto ...

# %% [markdown]
# The most frequent topics addressed in the prompts on the site according to model two are as follows:
# 1. Emails
# 2. Ticket Payments
# 3. Recycling
# 4. Monument Removal
# 5. Permits
# 6. Site Problems
# 7. Government Staff Info
# 8. Trash
# 9. License Renewal
# 10. Meeting Scheduling

# %%
# train a new model with modified topic sizes (topic size = 5)
topic_model_3 = BERTopic(language="english", top_n_words=5, min_topic_size=5,
                         calculate_probabilities=True, verbose=True)
topics, probs = topic_model_3.fit_transform(feedback)
# Out:
# Batches:   0%|          | 0/343 [00:00<?, ?it/s]
# 2023-02-01 22:59:31,269 - BERTopic - Transformed documents to Embeddings
# 2023-02-01 22:59:42,935 - BERTopic - Reduced dimensionality
# 2023-02-01 23:00:41,220 - BERTopic - Clustered reduced embeddings

# %%
# save model 3
topic_model_3.save("Site Feedback 3")
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/sparse/_index.py:125: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.

# %%
# most frequent topics: model 3
freq = topic_model_3.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                     Name
# 0      -1   3168                      -1_stock_in_the_and
# 1       0    165        0_email_contact_addresses_address
# 2       1    126  1_monuments_statues_history_confederate
# 3       2    126       2_recycling_recycle_glass_recycled
# 4       3    106             3_nola_nolagov_testing_links
# 5       4    101     4_occupational_license_renew_renewal
# 6       5     93             5_ticket_tickets_lost_number
# 7       6     85        6_helpful_very_helpfull_helpfully
# 8       7     76              7_phone_number_numbers_ring
# 9       8     76             8_parking_ticket_pay_tickets
# 10      9     76              9_trash_garbage_pick_pickup
# 11     10     72            10_ticket_pay_system_seatbelt
# 12     11     68              11_voting_ballot_vote_early
# 13     12     64          12_saints_retrieved_orleans_nfl
# 14     13     60         13_meeting_meetings_vcc_calendar
# 15     14     60                          14_de_que_la_el
# 16     15     58        15_summer_youth_apply_appointment
# 17     16     56                16_payment_swb_pay_portal
# 18     17     55               17_blank_page_scroll_empty
# 19     18     53                 18_bill_bills_water_help

# %%
topic_model_3.get_topic(0) # get the most frequent topic
# Out:
# [('email', 0.06306295807383784),
#  ('contact', 0.042607667027518586),
#  ('addresses', 0.028691001127881026),
#  ('address', 0.028293487574320687),
#  ('send', 0.014750601539763876)]

# %%
topic_model_3.get_topic(1) # get the 2nd most frequent topic
# Out:
# [('monuments', 0.019224474353420944),
#  ('statues', 0.017354823564770326),
#  ('history', 0.01622939093374297),
#  ('confederate', 0.015776148025344296),
#  ('removing', 0.010877707867818946)]

# %%
# Set labels for top 10 topics
topic_model_3.set_topic_labels({0: "Ticket Payment", 1: "Monument Removal",
                                2: "Government Staff Info", 3: "Permits", 4: "Site Problems",
                                5: "License Renewal", 6: "Positive reviews", 7: "Parking",
                                8: "Jobs", 9: "Parking Tickets"})

# Display model 3 bar chart
topic_model_3.visualize_barchart(top_n_topics=10, title='Model 3: Topic Word Scores',
                                 custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="dd3d9839-0626-4ca6-a776-3b4ec9f84796" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd3d9839-0626-4ca6-a776-3b4ec9f84796")) {                    Plotly.newPlot(                        "dd3d9839-0626-4ca6-a776-3b4ec9f84796",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.011685437239165986,0.012852234187100514,0.015111696787445207,0.01586835317611595,0.032977240241493434],"y":["seatbelt  ","system  ","tickets  ","pay  ","ticket  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.010304591552296882,0.015479648191900125,0.016305375449431267,0.017965412810346994,0.019571791629958795],"y":["removal  ","confederate  ","history  ","statues  ","monuments  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.019090106541128957,0.019389932023871213,0.025522191679970725,0.028860826147075924,0.040569574939626665],"y":["addresses  ","director  ","departments  ","department  ","staff  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.00982084563408727,0.010665865025370095,0.014130473405672604,0.03084817455568927,0.06158009672232733],"y":["how  ","utilityservice  ","status  ","permits  ","permit  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.006278620467506472,0.007218241732161722,0.00914978895555729,0.015815409969122028,0.041260038504795864],"y":["sites  ","red  ","testing  ","nolagov  ","nola  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.01613074040815985,0.036482402429039135,0.05091668232749123,0.054979782486564516,0.07050429586788266],"y":["renewing  ","renewal  ","renew  ","license  ","occupational  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.0173968796229823,0.03729585155115154,0.10365415897788305,0.29571941176754124,0.34571098106503334],"y":["necessary  ","helpfully  ","helpfull  ","very  ","helpful  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.015561234036968935,0.017104375488116358,0.01814947715563987,0.019435815659984652,0.03171302046673838],"y":["meters  ","park  ","signs  ","handicapped  ","parking  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.015516009296184597,0.017067131221536042,0.017332782398267896,0.038963930132322994,0.055547501294976744],"y":["employment  ","position  ","looking  ","jobs  ","job  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.010624516224874855,0.020801723032168994,0.023064337359194633,0.02541234467313931,0.0426423992477777],"y":["system  ","tickets  ","pay  ","ticket  ","parking  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcar ...

# %% [markdown]
# The most frequent topics addressed in the prompts on the site according to model three are as follows:
# 1. Ticket Payment
# 2. Monument Removal
# 3. Government Staff Info
# 4. Permits
# 5. Site Problems
# 6. License Renewal
# 7. Positive Reviews
# 8. Parking
# 9. Jobs
# 10. Parking Tickets

# %%
# train new model, add diversity
topic_model_4 = BERTopic(language="english", calculate_probabilities=True, diversity=0.5, verbose=True)
topics, probs = topic_model_4.fit_transform(feedback)
# Out:
# Batches:   0%|          | 0/343 [00:00<?, ?it/s]
# 2023-02-01 23:04:21,325 - BERTopic - Transformed documents to Embeddings
# 2023-02-01 23:04:33,644 - BERTopic - Reduced dimensionality
# 2023-02-01 23:04:53,301 - BERTopic - Clustered reduced embeddings

# %%
# save model 4
topic_model_4.save("Site Feedback 4")
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/sparse/_index.py:125: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.

# %%
# most frequent topics: model 4
freq = topic_model_4.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                      Name
# 0      -1   3192                      -1_act_have_on_stock
# 1       0    286     0_trash_recycling_schedule_collection
# 2       1    179           1_ticket_system_online_seatbelt
# 3       2    167       2_email_addresses_gmailcom_contacts
# 4       3    150          3_court_traffic_municipal_closed
# 5       4    149                4_file_incident_theft_copy
# 6       5    125               5_needs_dates_updating_page
# 7       6    125           6_orleans_city_water_signalized
# 8       7    122      7_monuments_confederate_removal_down
# 9       8    115           8_permit_status_electrical_file
# 10      9    106              9_volatility_hedge_roi_index
# 11     10    103              10_nolagov_testing_red_sites
# 12     11    102         11_occupational_renewal_link_form
# 13     12     99    12_assistance_eviction_apartment_brown
# 14     13     96  13_parking_handicapped_residential_meter
# 15     14     93           14_address_lookup_change_three3
# 16     15     93   15_staff_departments_contacts_directory
# 17     16     86        16_parking_ticket_citation_hearing
# 18     17     85           17_very_helpfull_helpfully_much
# 19     18     85             18_meetings_minutes_view_hdlc

# %%
topic_model_4.get_topic(0) # get the most frequent topic
# Out:
# [('trash', 0.040697007319088055),
#  ('recycling', 0.03695862671215279),
#  ('schedule', 0.009445447690058862),
#  ('collection', 0.008425491576472993),
#  ('drop', 0.007928536912403774),
#  ('can', 0.007774322754238641),
#  ('debris', 0.007550079758228907),
#  ('disposal', 0.0073847792699378466),
#  ('bin', 0.006954667446354731),
#  ('curbside', 0.006310569650274278)]

# %%
topic_model_4.get_topic(1) # get the 2nd most frequent topic
# Out:
# [('ticket', 0.045621073502770525),
#  ('system', 0.016960352283973724),
#  ('online', 0.013939594104824869),
#  ('seatbelt', 0.00906352071330143),
#  ('it', 0.008304434469663122),
#  ('payment', 0.006399756365548563),
#  ('j766472', 0.005832177489969202),
#  ('kira', 0.005832177489969202),
#  ('godchany', 0.005832177489969202),
#  ('cant', 0.005818448287848976)]

# %%
# Set labels for top 10 topics
topic_model_4.set_topic_labels({0: "Waste Disposal", 1: "Application Process",
                                2: "Ticket Payment", 3: "Building Permit", 4: "Tax and Bill Payments",
                                5: "License Renewal", 6: "Saints (NFL)", 7: "Location Info",
                                8: "Identifying Info", 9: "Incident Reports"})

# Display model 4 bar chart
topic_model_4.visualize_barchart(top_n_topics=10, title='Model 4: Topic Word Scores',
                                 custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e47e7564-3213-4019-bc9b-3bed08e804e0" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e47e7564-3213-4019-bc9b-3bed08e804e0")) {                    Plotly.newPlot(                        "e47e7564-3213-4019-bc9b-3bed08e804e0",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.0072081101662160914,0.008842625121982153,0.009247736879856154,0.033491435840022475,0.03532591746485051],"y":["disposal  ","hazardous  ","schedule  ","recycling  ","trash  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.012273226834474309,0.013408886204651468,0.013545391406992931,0.013548284340057042,0.06729468986999905],"y":["app  ","submit  ","assistance  ","process  ","application  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.008930686285103165,0.009639004369575885,0.0134616437527676,0.018077528289820222,0.041599327075664265],"y":["online  ","camera  ","number  ","pay  ","ticket  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.007347277837466108,0.008967092859442114,0.009342262597085555,0.011716793311515355,0.029746617063131562],"y":["vendor  ","need  ","status  ","building  ","permits  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.007020274650952342,0.009437120358780264,0.019736781370929875,0.02332412908548094,0.05253349982965639],"y":["online  ","real  ","bill  ","estate  ","tax  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.008135757157991617,0.010840188859187071,0.013417231044247009,0.04279617989136441,0.06863675667225627],"y":["tax  ","form  ","online  ","renewal  ","occupational  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.008922422647949655,0.009072700986105227,0.01938045914057735,0.02307186881864745,0.02685021891803391],"y":["record  ","nfl  ","retrieved  ","orleans  ","saints  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.009986242107664692,0.01231047888026583,0.017271455420315596,0.025599861015980472,0.02733948268486247],"y":["uptown  ","historic  ","districts  ","maps  ","zoning  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.01004391247730442,0.011111267796129991,0.012160656412538027,0.030539019335936772,0.05447478822052413],"y":["information  ","contacts  ","mail  ","addresses  ","contact  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.006898708482419296,0.008167562102803477,0.013401837096241122,0.015316413116186834,0.016701917655841624],"y":["tried  ","copy  ","theft  ","incident  ","file  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"col ...

# %% [markdown]
# The most frequent topics addressed in the prompts on the site according to model four are as follows:
# 1. Waste Disposal
# 2. Application Process
# 3. Ticket Payment
# 4. Building Permit
# 5. Tax and Bill Payments
# 6. License Renewal
# 7. Saints (NFL)
# 8. Location Info
# 9. Indentifying Info
# 10. Incident Reports

# %% [markdown]
# **Section Conclusion**
#
# The most significant and re-occuringing word clusters from the dataset were related to: Ticket Payments, Waste Disposal (Trash and Recycling), Obtaining/Renewing permits, Government Officials, and Monument Removal (the recent process of removing confederate monuments).
#
# While we can get an idea of what people are interested in, it is largely intermixed with what general problems people have with the government that are not in our scope to fix (although would make a good service learning  volunteering opportunity). The information in the dataset is generalized to the point where site suggestions only make up a small unorganized fraction of prompt requests and are relatively isolated from one another as they tend to be on a per case basis.
#
# Meaningful further analysis would most likely require sifiting through all 10,966 entries manually to cherry-pick meaningful and relevant suggestions that could hopefully be used to identify greater issues that can be remediated by our group.

# %% [markdown]
# ## Analyzing Calls For Service Data

# %% [markdown]
# Based on our above analysis, data related to the NOPD was a frequently mentioned topic of interest. There is also a substantial amount of data on this topic featured on the datadriven.nola.gov site. We have begun to analyze some of these datasets, as they are a potential topic for our final dashboard.
#
# Below, we imported the Calls For Service 2023 dataset. This dataset includes the type of service needed from NOPD, the location of the call, as well as some other topics. From this dataset we decided to mainly focus on the type of service and the location to see what crimes or services occur the most and if there are any correlations between the location of the crime or service needed. We hope to include this analysis in our dashboard.

# %%
service = pd.read_csv('Calls_for_Service_2023.csv')
display(service)
# Out:
#       NOPD_Item    Type                      TypeText Priority InitialType  \
# 0      A0599223  SEXOFF     SEX OFFENSE: GENERAL/MISC        2        ASLT
# 1      A0653023   THEFT                         THEFT        2       BURGV
# 2      A0700123  MENTAL  EMOTIONALLY DISTURBED PERSON        1      MENTAL
# 3      A0650123    PRIS            PRISONER TRANSPORT        1        PRIS
# 4      A0650423    PRIS            PRISONER TRANSPORT        1        PRIS
# ...         ...     ...                           ...      ...         ...
# 20429  A2189023    MISC       MISCELLANEOUS COMPLAINT        1        MISC
# 20430  A2179123   BURGV         BURGLARY FROM VEHICLE        0       BURGV
# 20431  A2219023    MISC       MISCELLANEOUS COMPLAINT        1        MISC
# 20432  A2164223  VEHSTO                VEHICLE STOLEN        0      VEHSTO
# 20433  A2150223    MISC       MISCELLANEOUS COMPLAINT        1        MISC
#
#                     InitialTypeText InitialPriority      MapX     MapY  \
# 0                    SIMPLE ASSAULT               1   3662781   517589
# 1             BURGLARY FROM VEHICLE               0   3706231   564651
# 2      EMOTIONALLY DISTURBED PERSON               2  37369000  3513814
# 3                PRISONER TRANSPORT               1   3692978   529549
# 4                PRISONER TRANSPORT               1   3692978   529549
# ...                             ...             ...       ...      ...
# 20429       MISCELLANEOUS COMPLAINT               1   3700556   518293
# 20430         BURGLARY FROM VEHICLE               0   3682428   529866
# 20431       MISCELLANEOUS COMPLAINT               1   3670740   553837
# 20432                VEHICLE STOLEN               0   3680616   543552
# 20433       MISCELLANEOUS COMPLAINT               1   3668908   552683
#
#                    TimeCreate  ... PoliceDistrict  \
# 0      01/06/2023 04:55:53 PM  ...              2
# 1      01/07/2023 07:05:08 AM  ...              7
# 2      01/07/2023 05:15:17 PM  ...              0
# 3      01/07/2023 06:08:31 AM  ...              4
# 4      01/07/2023 06:09:51 AM  ...              4
# ...                       ...  ...            ...
# 20429  01/22/2023 01:16:29 PM  ...              4
# 20430  01/22/2023 10:48:31 AM  ...              8
# 20431  01/22/2023 09:23:37 PM  ...              3
# 20432  01/22/2023 07:03:53 AM  ...              3
# 20433  01/22/2023 01:52:11 AM  ...              3
#
#                                Location   Blocks Council Districts  \
# 0      POINT (-90.12764112 29.91774739)   3690.0               1.0
# 1      POINT (-89.98874997 30.04582091)   1211.0               5.0
# 2                           POINT (0 0)      NaN               NaN
# 3      POINT (-90.03189701 29.94972492)   9160.0               3.0
# 4      POINT (-90.03189701 29.94972492)   9160.0               3.0
# ...                                 ...      ...               ...
# 20429  POINT (-90.00837902 29.91853377)   3588.0               3.0
# 20430   POINT (-90.0651976 29.95092008)   8996.0               3.0
# 20431  POINT (-90.10128725 30.01718249)  13860.0               1.0
# 20432  POINT (-90.07043977 29.98860718)   8455.0               4.0
# 20433  POINT (-90.10711582 30.01406487)  10753.0               1.0
#
#       Self-Reported Neighborhood Organizations (SRNOs) Boundaries  \
# 0                                                   42.0
# 1                                                  158.0
# 2                                                    NaN
# 3                                                    2.0
# 4                                                    2.0
# ...                                                  ...
# 20429                                                2.0
# 20430                                               23.0
# 20431                                              106.0
# 20432                                              134.0
# 20433                                              106.0
#
#       (ALTERNATE) - Neighborhood Statistical Areas Zip Codes  \
# 0                                             72.0    3767.0
# 1                                             20.0    4149.0
# 2                                              NaN       NaN
# 3                                              1.0    3456.0
# 4                                              1.0    3456.0
# ...                                            ...       ...
# 20429                                          5.0    4153.0
# 20430                                         69.0    4152.0
# 20431                                         38.0    3772.0
# 20432                                         21.0    3768.0
# 20433                                         38.0    3772.0
#
#       Neighborhood Organizations Police Districts  Census - 2010
# 0                           42.0              3.0         3690.0
# 1                          158.0              1.0         1211.0
# 2                            NaN              NaN            NaN
# 3                            2.0              2.0         9160.0
# 4                            2.0              2.0         9160.0
# ...                          ...              ...            ...
# 20429                        2.0              2.0         3588.0
# 20430                       23.0              5.0         8996.0
# 20431                      106.0              7.0        13860.0
# 20432                      134.0              7.0         8455.0
# 20433                      106.0              7.0        10753.0
#
# [20434 rows x 29 columns]

# %%
display(service['TypeText'])
# Out:
# 0           SEX OFFENSE: GENERAL/MISC
# 1                               THEFT
# 2        EMOTIONALLY DISTURBED PERSON
# 3                  PRISONER TRANSPORT
# 4                  PRISONER TRANSPORT
#                      ...
# 20429         MISCELLANEOUS COMPLAINT
# 20430           BURGLARY FROM VEHICLE
# 20431         MISCELLANEOUS COMPLAINT
# 20432                  VEHICLE STOLEN
# 20433         MISCELLANEOUS COMPLAINT
# Name: TypeText, Length: 20434, dtype: object

# %%
type = service['TypeText']
type.value_counts()
# Out:
# MISCELLANEOUS COMPLAINT             5131
# DISORDERLY CONDUCT                  1035
# AREA CHECK                           919
# INVESTIGATION: POLICE DEPARTMENT     849
# VEHICLE STOLEN                       683
#                                     ...
# SEX OFFENDER REGISTRATION CHECK        1
# SEXUAL BATTERY                         1
# TRUANT VIOLATION                       1
# ATTACHMENT                             1
# TRAFFIC INCIDENT                       1
# Name: TypeText, Length: 170, dtype: int64

# %%
display(service["TypeText"].value_counts())
service["TypeText"].value_counts().head(10).plot.pie(y='mass', figsize=(8, 8),title = 'NOPD Service Calls')
# Out:
# MISCELLANEOUS COMPLAINT             5131
# DISORDERLY CONDUCT                  1035
# AREA CHECK                           919
# INVESTIGATION: POLICE DEPARTMENT     849
# VEHICLE STOLEN                       683
#                                     ...
# SEX OFFENDER REGISTRATION CHECK        1
# SEXUAL BATTERY                         1
# TRUANT VIOLATION                       1
# ATTACHMENT                             1
# TRAFFIC INCIDENT                       1
# Name: TypeText, Length: 170, dtype: int64

# %%
NOLA = gpd.read_file('nola.shx')

# %%
NOLA
# Out:
#                                                  geometry
# 0       POLYGON ((-90.07616 29.98025, -90.07632 29.980...
# 1       POLYGON ((-90.01666 30.03358, -90.01665 30.033...
# 2       POLYGON ((-90.12216 29.91968, -90.12224 29.919...
# 3       POLYGON ((-90.02074 30.02099, -90.02070 30.020...
# 4       POLYGON ((-89.99281 30.04027, -89.99275 30.040...
# ...                                                   ...
# 154767  POLYGON ((-90.06904 30.01728, -90.06903 30.017...
# 154768  POLYGON ((-89.99791 30.02397, -89.99805 30.023...
# 154769  POLYGON ((-90.07671 30.02169, -90.07668 30.021...
# 154770  POLYGON ((-90.01196 29.91488, -90.01192 29.914...
# 154771  POLYGON ((-89.98835 29.92261, -89.98835 29.922...
#
# [154772 rows x 1 columns]

# %%
NOLA.plot()

# %%
service = pd.read_csv('Calls_for_Service_2023.csv')
service['geometry'] = service['Location']

# %%
service['geometry'] = gpd.GeoSeries.from_wkt(service['geometry'])
my_geo_df = gpd.GeoDataFrame(service, geometry='geometry')

# %%
test = my_geo_df[4:100]
test.plot()

# %%
fig, ax = plt.subplots(figsize=(20,20))

NOLA.plot(ax=ax,alpha=1,linewidth=1,cmap="cividis")
test.plot(ax=ax)
